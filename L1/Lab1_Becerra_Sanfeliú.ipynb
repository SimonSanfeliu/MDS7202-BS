# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2023</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Nicolás Becerra
# - Nombre de alumno 2: Simón Sanfeliú

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/SimonSanfeliu/MDS7202-BS

# %% [markdown]
# ## Reglas:
#
# - Fecha de entrega: 6 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de 2 personas**
# - Asistencia **obligatoria** a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.
# - **Ausentes tienen nota máxima 6.0**.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Pueden usar cualquer material del curso que estimen conveniente.
# - Asistencia obligatoria a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# 1. `Git` es un sistema de control de versiones distribuido, lo que implica que se van controlando las distintas versiones de distintos códigos de un proyecto en distintos dispositivos al mismo tiempo (en computadores locales y en un servidor).
#
# 2.
#    * `Git` es un software, `Github` es un servicio: `Git` es un programa instalado en un ordenador en el cual se ejecutan comando, mientras que Github resulta ser un servicio que interactúa y almacena repositorios de `Git`.
#    * `Git` es una herramienta de comando, `Github` es una herramienta de interfaz gráfica: `Git`, al ser un software, interactúa con los repositorios a través de comando en la terminal, mientras que `Github` es una interfaz gráfica que permite interactuar con los repositorios de Git de una manera más amigable y atractiva.
#    * `Git` crea repositorios locales para trackear cambios locales, `Github` es un espacio en la nube para almacenar repositorios: `Git` es capaz de generar repositorios locales en el ordenador en el cual se realizan los cambios, trackeando estos cambios en un mismo ordenador, mientras que `Github` es un servicio que permite almacenar repositorios en la nube al generar una copia de estos.
#
# 3. En el contexto de `Git` y `Github`, `hash` es un código alfanumérico de 40 caracteres que permite identificar distintos conjuntos de datos. `Git` utiliza el hash SHA1. Este código puede apuntar a un `blob`, `tree` o `commit`, pudiendo identificar distintas versiones de estos con sus códigos `hash` respectivos o con tan sólo con los primeros términos de dichos códigos. Un ejemplo de esto sería el código `c8b1a62d7299552b0654f930d695b33109214111` de más adelante en el laboratorio.
#
# 4. La estructura de datos de `Git` se compone principalmente de 4 objetos: `blobs`, `trees`, `commits` y `hashes`. Los `blobs` son los contenidos de los archivos almacenados y se genera un `blob` por cada modificación del cada archivo que se almacene en el repositorio. Los `trees` son directorios para los `blobs` y otros `trees` (análogo a las carpetas de un ordenador), habiendo siempre un `tree` en la raíz del repositorio. Los `commits` son los registros de los cambios realizados en el repositorio, apuntan a un `tree` en específico, mostrando cómo lucía el proyecto en un cierto punto en el tiempo. Por último, los `hashes` son identificadores únicos de cada objeto de `Git`, los cuales se generan a partir de los contenidos de los objetos, por ende, sirven para dirigirse a un `blob`, `tree` o `commit` en específico.
#
# 5. Para crear un repositorio, se debe usar el comando `git init /ruta/del/directorio`. Por su parte, para hacer el seguimiento de los cambios en los archivos se puede usar `git log` para ver el historial de `commits` hechos al repositorio o también se puede usar `git status` para ver el estado de todos los archivos del repositorio, tanto aquellos que estén en un `commit` como aquellos que aún no son agregados a uno.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# 6. Falso. Los problemas de líneas de códigos entre distintas ramas deben resolverse manualmente, pero `Git` detectará los conflictos y los mostrará al ocurrirse.
#
# 7. Falso. El comando `git pull` trae las versiones de los códigos del proyecto que están en el repositorio remoto al repositorio local, mezclándose éstas con las que se tengan localmente. Para que este comando funcione, ya se debe tener el repositorio local que se conecta con el remoto. En cambio, `git clone` clona el repositorio, siendo este comando usado para traer por primera vez el repositorio al ambiente local.
#
# 8. Falso. El comando `git status` entrega el estado de todos los archivos del repositorio, tanto aquellos que estén declarados en `commits` como los que no. Por su parte, `git log` sólo entrega el historial de `commits`.
#
# 9. Verdadero. Al ser un sistema de control de versiones, es posible volver a versiones anteriores que sean más estables que las actuales y poder deshacer cambios que resulten conflictivos o ineficientes.
#
# 10. Falso. Para enviar cambios al repositorio remoto se utiliza `git push`, pero lo que se manda con dicho comando son los `commits` hechos con `git commit`.

# %% [markdown]
# Por último, investigue y comente para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# 11. El comando `git stash` almacena temporalmente cualquier cambio en el código en un *stash* (escondite). Coge los cambios que no han sido confirmado, los guarda aparte y los limpia del directorio de trabajo, permitiendo que el usuario tenga ahora la libertad de cambiar de rama, hacer cambios o cualquier acción que quiere ejecutar sobre el repositorio. Cuando el usuario quiera volver a los cambios que guardó, puede usar `git stash apply` para recuperarlos O `git stash pop` para recuperarlos y eliminarlos del stash. Como se aprecia, este comando sirve principalmente por si se necesita cambiar rápidamente de contexto y no quieres perder los cambios que has hecho en el código, pero tampoco quieres hacer un commit al proyecto todavía.
#
# 12. El comando `git reset <archivo>` quita los cambios del área de *staging*, en donde se definen todos los cambios que irán en el `commit`. Esto lo hace dejando el repositorio trabajado sin cambios, por lo que el archivo al ser *unstaged* no sobrescribe ningún cambio. Por su parte, `git revert <commit>` deshace todos los cambios que fueron *staged* en el `commit` especificado y luego estos se aplican a la rama en la que se esté trabajando.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1: https://github.com/nbcrra37/nbcrra37 </code>
#
# <code>Link Presentacion 2: https://github.com/SimonSanfeliu/SimonSanfeliu </code>

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# Para clonar un repositorio usando los comandos de `Git`, se consigue la ruta HTTPS del repositorio y se escribe el siguiente comando en la consola: <code>git clone https://github.com/MDS7202/lab1.git</code>.

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# Leyendo el archivo `readme.md`, se sabe que el objetivo del proyecto es emular sonidos de animales. El proyecto consta de 3 archivos: `readme.md`, el cual indica de qué trata el proyecto de forma resumida; `main.py`, archivo que debe correrse para iniciar el proyecto y que este funcione. Finalmente, el archivo `animales.py`, que es el código que simula los ruidos de los animales que se le ingresen al programa.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# El proyecto posee 3 ramas: la primera rama creada, `fix-ifs` que tiene sólo los archivos `readme.md` y `main.py`, en donde este último contenía también la función de sonidos de animales del archivo `animales.py`; la rama `new_features`, en donde se separó la función de ruidos de animales del archivo `main.py` en su propio archivo y la rama `main`, que es la rama principal del proyecto y donde se lleva el flujo principal de este. Esta última rama es idéntica a la rama `new_features`, ya que es la rama más nueva y eficiente por lo que se define esta como la principal, pero haciendo la distinción con su versión original en caso de que se hagan más versiones del proyecto.
#
# El repositorio consta de 4 `commits`: 2 el 22 de marzo de 2023 y 2 el 23 de marzo de 2023. El primero es la creación del proyecto, agregando el archivo `main.py` con el esqueleto de cómo operar el proyecto y el archivo `readme.md` con la información de éste. Que el mensaje de este `commit` sea sólo "primer commit" indica que es el primer cambio del repositorio, pero podría ser un poco más explícito y decir que es el inicio del proyecto. De igual forma, cumple su función informativa. El segundo agrega la función emuladora de sonidos de animales, lo cual se explicita con el mensaje del `commit`. El tercero separa la función emuladora en un archivo aparte y además crea una nueva rama con estas nuevas funcionalidades, para luego hacer una `merge` con la rama principal. Mientras que el mensaje "Se separa el proyecto en módulos" es sumamente explicativo, se podría especificar el hecho de la creación de nuevas ramas. Finalmente, el último `commit` del repositorio consiste en la creación de la rama `fix-ifs`, en la cual, como dice el mensaje homólogo al nombre de la rama, se arreglan los if's de la función emuladora. El mensaje es informativo, a pesar de no mencionar la creación de una nueva rama, pero el problema está en que se está editando la función emuladora en el archivo `main.py`, cuando realmente en la rama principal esta función está en un archivo aparte.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# Se utilizaron los comandos `git blame main.py` y `git blame animales.py`, detectando la fuente del problema en un error de código dentro del archivo `animales.py`, el cual fue escrito completamente por el usuario `mezosky`, quien además copio o movió líneas de otro archivo cuyo autor original es `seba` (esta información se consigue con la flag `-C`).
#
# ```cmd
# PS C:\Users\...\lab1> git blame animales.py
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  1) def animales(input):
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  2)
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  3)     '''
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  4)     Como hace el animalito?
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  5)     '''
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  6)
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  7)     if input.lower() == 'gato':
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  8)         print('miau')
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300  9)     if input.lower() == 'perro':
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 10)         print('guau')
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 11)     if input.lower() == 'fox':
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 12)         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 13)     else:
# 362fe21e (mezosky 2023-03-23 21:47:34 -0300 14)         raise ValueError('animal no reconocido :(')
# ```
#
#
# El orden en que se escribieron los `if` no excluyen a la función de recorrer los siguientes casos, por ende, si el input es *gato* o *perro*, el programa enviará el sonido respectivo, pero además chequeará el `if` de *fox*. El problema con esto es que si este último `if` no es verdadero, el código accederá directamente al condicional `else` ya que está escrito justo a continuación, lo que levantará el error a pesar de que el input sea *gato* o *perro*. Por ende, el error no se levanta solo en el caso que `input.lower() == "fox"`. Para solucionar esto, se debe trabajar con `elif` en vez de `if` para que el código no siga recorriendo los `if` restantes si ya se cumplió uno de ellos, como se muestra a continuación:
#
# ```python
# def animales(input):
#
#     '''
#     Como hace el animalito?
#     '''
#
#     if input.lower() == 'gato':
#         print('miau')
#     elif input.lower() == 'perro':
#         print('guau')
#     elif input.lower() == 'fox':
#         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#     else:
#         raise ValueError('animal no reconocido :(')

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# Usando el comando `git show <commit>` es posible ver los cambios que se hicieron en cada `commit`. Los cambios que se hicieron en cada uno de los `commit` son los siguientes:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
#   - Este `commit` agrega una función, por lo tanto, modifica un archivo del repositorio. Inicialmente, se añadió la función `animales` al archivo `main.py`.
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
#   - Este `commit` modifica los directorios del repositorio, separando la función `animales` del archivo `main.py` y creando un archivo `animales.py` para esta función. Además, esto commit involucra otras ramas, como `new_features`, donde probablemente se implementó esta separación en módulos del archivo original.
# - `25543a3baf77292baf849726784ca005473acab1`
#   - Este `commit` corrige los errores presentes en los códigos de la rama principal, los cuales fueron abordados en la parte anterior. Además, se realiza como primer `commit` de una rama secundaria llamada `fix-ifs`.
#
# En resumen, el primer `commit` modifica un archivo, el segundo generó un archivo nuevo desde una rama principal para luego aplicar los cambios en el `main.py` y el tercero corrige errores de los códigos de las ramas principales en una nueva rama, pero sin incorporar los cambios al `main.py`.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# Al intentar hacer la `merge`, lanza el siguiente error: <code>CONFLICT (content): Merge conflict in main.py</code>. Esto quiere decir que hay un conflicto en el archivo `main.py` que tienen ambas ramas, lo que implica que los archivos tienen líneas de código correspondientes con distinto código. Esto impide que puedan unirse/mezclarse las ramas, ya que, para hacerlo, si tienen archivos en común (con el mismo nombre y extensión), estos deben tener sus líneas de código correspondientes idénticas. Si es que no lo son, se tienen distintas funcionalidades y modos de uso entre ramas, por lo que no serían compatibles para mezclarse.
#
# En concreto, esto ocurre debido a que se arreglaron los if's en la función emuladora de sonidos de animales cuando ésta aún se encontraba en el archivo `main.py`, siendo que la rama principal ahora tiene dicha función en un archivo aparte. Luego, las líneas de código correspondientes en este archivo difieren entre sí, de ahí que se genere el conflicto.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# Se crea una nueva rama usando `git branch newbranch`, luego se ingresa a dicha rama con `git switch newbranch` y se corrige el error en el archivo `animales.py` con el siguiente código:
#
# ```python
# def animales(input):
#
#     '''
#     Como hace el animalito?
#     '''
#
#     if input.lower() == 'gato':
#         print('miau')
#     elif input.lower() == 'perro':
#         print('guau')
#     elif input.lower() == 'fox':
#         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#     else:
#         raise ValueError('animal no reconocido :(')
# ```
#
# Se modificaron las líneas 9 y 11, correspondientes a los `if` de *perro* y *fox* respectivamente, cambiándolos por `elif` para que el código no siga recorriendo los `if` restantes si ya se cumplió uno de ellos. El archivo `main.py` se mantiene igual al de la rama principal. Con todo esto hecho, se realiza una `merge` con la rama `main` la cual no genera conflictos.

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=87110296-876e-426f-b91d-aaf681223468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
